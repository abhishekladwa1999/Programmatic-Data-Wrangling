# %% [markdown]
# # 0. Finding Insights
#
# I began this venture just by gaining some base familiarity with the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie_data = "TMDB_movies.csv"
df = pd.read_csv(movie_data)

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df[['genres']]
# Out:
#                                                  genres
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                 []
# 4802                [{"id": 99, "name": "Documentary"}]
#
# [4803 rows x 1 columns]

# %% [markdown]
# # Insight 1: finding a link between original language and revenue of Films
#
# As my first insight, I wanted to look into a potential (and perhaps
# somewhat overlooked and maybe even unlikely) link between the revenue of the films, and the original language that the film was produced in.
#
# After drawing up a list of original languages and comparing them to the average revenue for the films of the that language, I could immediately some surprises.
#
# Due to english being the most commonly spoken, and deemed 'international' language, it was expected that the English language films would top substantially in terms of revenue compared to other language. However, Telugu language films (ISO code 'te') seems to have displaced English, with a higher revenue.
#
# This could be due to more films produced in English, and more commercial failures bringing down the overall average revenue of English language films, but it also is an interesting insight to see that Telugu films, and perhaps to a wider extent other language films, could be more financially successful, despite being less spoke or understood around the world.
#
# Furthermore, when looking into and comparing budget, we can see that the average budget given for Telugu films, is also the highest budget given.

# %%
df.groupby('original_language')[['original_language', 'revenue']].mean().sort_values(by = 'revenue', ascending = False)
# Out:
# <ipython-input-9-2c7a8af29217>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('original_language')[['original_language', 'revenue']].mean().sort_values(by = 'revenue', ascending = False)
#                         revenue
# original_language
# te                 1.000000e+08
# en                 8.647885e+07
# ja                 6.602892e+07
# xx                 5.526056e+07
# zh                 4.173498e+07
# cn                 3.374016e+07
# da                 2.989889e+07
# ko                 2.535645e+07
# es                 1.865218e+07
# de                 1.396191e+07
# fr                 1.246151e+07
# th                 1.203408e+07
# pl                 1.070000e+07
# af                 9.879971e+06
# ru                 9.510074e+06
# hi                 7.447231e+06
# ...

# %%
df.groupby('original_language')[['original_language', 'revenue', 'budget']].mean().sort_values(by = 'budget', ascending = False)
# Out:
# <ipython-input-10-dfd0602b10b8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('original_language')[['original_language', 'revenue', 'budget']].mean().sort_values(by = 'budget', ascending = False)
#                         revenue        budget
# original_language
# te                 1.000000e+08  4.000000e+07
# en                 8.647885e+07  3.039436e+07
# zh                 4.173498e+07  2.202560e+07
# ja                 6.602892e+07  1.429361e+07
# ko                 2.535645e+07  1.429091e+07
# ru                 9.510074e+06  1.397273e+07
# xx                 5.526056e+07  1.200000e+07
# cn                 3.374016e+07  1.072641e+07
# tr                 0.000000e+00  1.000000e+07
# da                 2.989889e+07  9.742857e+06
# ...

# %% [markdown]
# # Insight 2: concluding on a take away on an insight into revenue
#
# A key finding that was found upon conducting analysis on how the revenues of all the films, was how how on average, most films in the database fit into one single range of values, specifically on the lowest end of values, compared to the revenue ranges of other films in the database.
#
#
# Taking insight from the distribution plot of revenue against count, I also decided to further confirm this trend with addition of price buckets, and a 'box-office' grouping, to showcase that this had the same trend as the original distribution plot.
#
# While an insight could initially be drawn suggesting that most of the films in the dataset produced low revenue film, upon further insight and looking into the values, we can conclude that there are multiple films that act as outliers which cause most of these films to fall into the lower band. Upon separating the distribution of revenues by film in buckets, we can also see this trend.
#
# This concludes that most of the films, while on the lowest band of revenue, actually do portray more of stanadard average, as the majority of films fall into this revenue band, with there being several outliers in the data that fall into much larger revenue bands. An example of this would be Avatar.

# %%
sns.displot(
            x = 'revenue',
            data = df,
            bins = 5
           )

plt.show()

# %%
df[['revenue']].sort_values(by = 'revenue', ascending = False)
# Out:
#          revenue
# 0     2787965087
# 25    1845034188
# 16    1519557910
# 28    1513528810
# 44    1506249360
# ...          ...
# 3200           0
# 3199           0
# 3197           0
# 3194           0
# 4802           0
#
# [4803 rows x 1 columns]

# %%
box_office = df[['id','title', 'budget', 'genres', 'popularity', 'revenue']].copy()

box_office.drop_duplicates(keep = 'last', inplace = True)

revenue_buckets = [0, 500000000, 1000000000, 1500000000, 2000000000, 2500000000, 3000000000]
revenue_name = ['very low revenue', 'low revenue', 'moderate revenue', 'high revenue', 'very high revenue', 'immensely high revenue']

box_office['Price Buckets'] = pd.cut(box_office['revenue'],
                                  bins = revenue_buckets,
                                  labels = revenue_name,
                                  include_lowest = True)

# %%
box_office.head()
# Out:
#        id                                     title     budget  \
# 0   19995                                    Avatar  237000000
# 1     285  Pirates of the Caribbean: At World's End  300000000
# 2  206647                                   Spectre  245000000
# 3   49026                     The Dark Knight Rises  250000000
# 4   49529                               John Carter  260000000
#
#                                               genres  popularity     revenue  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  150.437577  2787965087
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...  139.082615   961000000
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  107.376788   880674609
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...  112.312950  1084939099
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   43.926995   284139100
#
#             Price Buckets
# 0  immensely high revenue
# 1             low revenue
# 2             low revenue
# ...

# %%
sns.countplot(x = 'Price Buckets',
              data = box_office,
              palette = 'magma')

plt.xlabel('Price Group')
plt.ylabel('Number of Films')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('box office')

plt.show()

# %%
def box_office_grouping(x):
    if x <500000000:
        return '0-0.5 Bil.'
    elif x<1000000000:
        return '5-10 Bil.'
    elif x<1500000000:
        return '10-15 Bil.'
    elif x<2000000000:
        return '15-20 Bil.'
    elif x<2500000000:
        return '20-25 Bil.'
    elif x<3000000000:
        return '25-30 Bil.'
    else:
        return '30+ Bil.'

df['box_office_group'] = df['revenue'].apply(box_office_grouping)



plt.figure(figsize = (16,9))

sns.countplot(data = df,
              x = 'box_office_group',
              palette = 'viridis',
              order = ['0-0.5 Bil.','5-10 Bil.','10-15 Bil.','15-20 Bil.','20-25 Bil.','25-30 Bil.','30+ Bil.'])

plt.show()

# %% [markdown]
# # visualisation 1: Comparing Budget to popularity and revenue

# %% [markdown]
# This visualisation aims to showcase a general overall picture of how the Budget, Popularity, Revenue and Budget all correlate relative to each other, with the aid of a heatmap to visualise this.

# %%
df[['budget','popularity','revenue','vote_count']]
# Out:
#          budget  popularity     revenue  vote_count
# 0     237000000  150.437577  2787965087       11800
# 1     300000000  139.082615   961000000        4500
# 2     245000000  107.376788   880674609        4466
# 3     250000000  112.312950  1084939099        9106
# 4     260000000   43.926995   284139100        2124
# ...         ...         ...         ...         ...
# 4798     220000   14.269792     2040920         238
# 4799       9000    0.642552           0           5
# 4800          0    1.444476           0           6
# 4801          0    0.857008           0           7
# 4802          0    1.929883           0          16
#
# [4803 rows x 4 columns]

# %%
df2 = df[['budget','popularity','revenue','vote_count']]

# %%
df2
# Out:
#          budget  popularity     revenue  vote_count
# 0     237000000  150.437577  2787965087       11800
# 1     300000000  139.082615   961000000        4500
# 2     245000000  107.376788   880674609        4466
# 3     250000000  112.312950  1084939099        9106
# 4     260000000   43.926995   284139100        2124
# ...         ...         ...         ...         ...
# 4798     220000   14.269792     2040920         238
# 4799       9000    0.642552           0           5
# 4800          0    1.444476           0           6
# 4801          0    0.857008           0           7
# 4802          0    1.929883           0          16
#
# [4803 rows x 4 columns]

# %%
df2.corr()
# Out:
#               budget  popularity   revenue  vote_count
# budget      1.000000    0.505414  0.730823    0.593180
# popularity  0.505414    1.000000  0.644724    0.778130
# revenue     0.730823    0.644724  1.000000    0.781487
# vote_count  0.593180    0.778130  0.781487    1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(data = df2.corr(),
            annot = True,
            cmap = 'winter',
            vmin = 0,
            vmax = 1)
plt.show()

# %% [markdown]
# # Visualisation 2: looking at outliers in vote count and vote average

# %% [markdown]
# This visualisation is a general look into how the vote counts (and to an extent the vote average as well) compared to each other relatively, showing that most of the vote count distribution fall into the lower end of the spectrum, however the vote average distribution falls further along the spectrum.

# %%
sns.displot(data = df['vote_count'],
            height = 10)

plt.show()

# %%
sns.displot(data = df['vote_average'],
            height = 10)

plt.show()

# %%
plt.figure(figsize = (20,5))
sns.boxplot(data = df['vote_count'],
            orient = 'h',
            whis = 1.5)

plt.show()

# %%
plt.figure(figsize = (20,5))
sns.boxplot(data = df['vote_average'],
            orient = 'h',
            whis = 1.5)

plt.show()

# %% [markdown]
# # visualisation 3: revenue buckets

# %% [markdown]
# This visualisation aims to show the general trend of the revenues of all the films in the data set, aiming to depict how to proportion of the films revenue wise compare to each other.

# %%
sns.displot(
            x = 'revenue',
            data = df,
            bins = 5
           )

plt.show()

# %%
df[['revenue']].sort_values(by = 'revenue', ascending = False)
# Out:
#          revenue
# 0     2787965087
# 25    1845034188
# 16    1519557910
# 28    1513528810
# 44    1506249360
# ...          ...
# 3200           0
# 3199           0
# 3197           0
# 3194           0
# 4802           0
#
# [4803 rows x 1 columns]

# %%
box_office = df[['id','title', 'budget', 'genres', 'popularity', 'revenue']].copy()

box_office.drop_duplicates(keep = 'last', inplace = True)

revenue_buckets = [0, 500000000, 1000000000, 1500000000, 2000000000, 2500000000, 3000000000]
revenue_name = ['very low revenue', 'low revenue', 'moderate revenue', 'high revenue', 'very high revenue', 'immensely high revenue']

box_office['Price Buckets'] = pd.cut(box_office['revenue'],
                                  bins = revenue_buckets,
                                  labels = revenue_name,
                                  include_lowest = True)

# %%
box_office.head()
# Out:
#        id                                     title     budget  \
# 0   19995                                    Avatar  237000000
# 1     285  Pirates of the Caribbean: At World's End  300000000
# 2  206647                                   Spectre  245000000
# 3   49026                     The Dark Knight Rises  250000000
# 4   49529                               John Carter  260000000
#
#                                               genres  popularity     revenue  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  150.437577  2787965087
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...  139.082615   961000000
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  107.376788   880674609
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...  112.312950  1084939099
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   43.926995   284139100
#
#             Price Buckets
# 0  immensely high revenue
# 1             low revenue
# 2             low revenue
# ...

# %%
sns.countplot(x = 'Price Buckets',
              data = box_office,
              palette = 'magma')

plt.xlabel('Price Group')
plt.ylabel('Number of Films')

plt.xticks(rotation = 45,
           horizontalalignment = 'right',
           fontweight = 'light',
           fontsize = 'large',
          )
plt.title('box office')

plt.show()

# %%
def box_office_grouping(x):
    if x <500000000:
        return '0-0.5 Bil.'
    elif x<1000000000:
        return '5-10 Bil.'
    elif x<1500000000:
        return '10-15 Bil.'
    elif x<2000000000:
        return '15-20 Bil.'
    elif x<2500000000:
        return '20-25 Bil.'
    elif x<3000000000:
        return '25-30 Bil.'
    else:
        return '30+ Bil.'

df['box_office_group'] = df['revenue'].apply(box_office_grouping)



plt.figure(figsize = (16,9))

sns.countplot(data = df,
              x = 'box_office_group',
              palette = 'viridis',
              order = ['0-0.5 Bil.','5-10 Bil.','10-15 Bil.','15-20 Bil.','20-25 Bil.','25-30 Bil.','30+ Bil.'])

plt.show()

# %% [markdown]
# # Movie 1: insights - Avatar

# %% [markdown]
# I found Avatar interesting, as despite being the highest revenue film in the dataset, it falls 19th highest in budget, which despite still being very high, does still produce an immensely high revenue compared to the rest of the top 10 highest revenues.

# %%
df.iloc[[0]]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
# ...

# %%
df[['original_title','budget','revenue']].sort_values(by = 'revenue', ascending = False)
# Out:
#                                 original_title     budget     revenue
# 0                                       Avatar  237000000  2787965087
# 25                                     Titanic  200000000  1845034188
# 16                                The Avengers  220000000  1519557910
# 28                              Jurassic World  150000000  1513528810
# 44                                   Furious 7  190000000  1506249360
# ...                                        ...        ...         ...
# 3200                           La Fille du RER          0           0
# 3199  Red Riding: In the Year of Our Lord 1974          0           0
# 3197                        Flammen & Citronen    6500000           0
# 3194                            All or Nothing    9000000           0
# 4802                         My Date with Drew          0           0
#
# [4803 rows x 3 columns]

# %%
df[['original_title','budget','revenue']].sort_values(by = 'budget', ascending = False).head(20)
# Out:
#                                  original_title     budget     revenue
# 17  Pirates of the Caribbean: On Stranger Tides  380000000  1045713802
# 1      Pirates of the Caribbean: At World's End  300000000   961000000
# 7                       Avengers: Age of Ultron  280000000  1405403694
# 10                             Superman Returns  270000000   391081192
# 4                                   John Carter  260000000   284139100
# 6                                       Tangled  260000000   591794936
# 5                                  Spider-Man 3  258000000   890871626
# 13                              The Lone Ranger  255000000    89289910
# 46                   X-Men: Days of Future Past  250000000   747862775
# 22          The Hobbit: The Desolation of Smaug  250000000   958400000
# 26                   Captain America: Civil War  250000000  1153304495
# 9            Batman v Superman: Dawn of Justice  250000000   873260194
# ...

# %% [markdown]
# # Movie 2: insights - March of the penguins
#
#  When comparing the highest grossing film of each genre to the highest grossing film of the 'Documentary' genre: March of the Penguins, I discovered that it was the only film of the highest grossing film of its respective genre to not be in English, but rather in French.
#
#  While at first, this may not seem very insightful, it does seems interesting that while every other film genre is dominated by the English language film market, the fact that a French documentary has outranked all other English documentaries in revenue *could* suggest less interest in documentaries and more interest towards all other genres across English languages speakers in general. However, this would definitely need to be backed up with further analysis.

# %%
import ast
def extract_genres(x):
    x = ast.literal_eval(x)
    Genres = []

    for item in x:
        Genres.append(item['name'])

    return Genres

df['extracted_genres'] = df['genres'].apply(extract_genres)

# %%
df[['extracted_genres']].head(5000)
# Out:
#                                    extracted_genres
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, Science Fiction]
# ...                                             ...
# 4798                      [Action, Crime, Thriller]
# 4799                              [Comedy, Romance]
# 4800             [Comedy, Drama, Romance, TV Movie]
# 4801                                             []
# 4802                                  [Documentary]
#
# [4803 rows x 1 columns]

# %%
df[['extracted_genres','title','revenue']]
# Out:
#                                    extracted_genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# 4              [Action, Adventure, Science Fiction]
# ...                                             ...
# 4798                      [Action, Crime, Thriller]
# 4799                              [Comedy, Romance]
# 4800             [Comedy, Drama, Romance, TV Movie]
# 4801                                             []
# 4802                                  [Documentary]
#
#                                          title     revenue
# 0                                       Avatar  2787965087
# 1     Pirates of the Caribbean: At World's End   961000000
# 2                                      Spectre   880674609
# 3                        The Dark Knight Rises  1084939099
# ...

# %%
df[df['genres'].str.contains('Action')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
# ...

# %%
df[df['genres'].str.contains('Adventure')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
# ...

# %%
df[df['genres'].str.contains('Comedy')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#        budget                                             genres  \
# 546  74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
#
#                          homepage      id  \
# 546  http://www.minionsmovie.com/  211672
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
#
#     original_title                                           overview  \
# 546        Minions  Minions Stuart, Kevin and Bob are recruited by...
#
#      popularity                               production_companies  ...  \
# 546  875.581305  [{"name": "Universal Pictures", "id": 33}, {"n...  ...
#
#         revenue runtime                          spoken_languages    status  \
# 546  1156730962    91.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline    title vote_average  \
# ...

# %%
df[df['genres'].str.contains('Crime')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres  \
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                              homepage     id  \
# 3  http://www.thedarkknightrises.com/  49026
#
#                                             keywords original_language  \
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#           original_title                                           overview  \
# 3  The Dark Knight Rises  Following the death of District Attorney Harve...
#
#    popularity                               production_companies  ...  \
# 3   112.31295  [{"name": "Legendary Pictures", "id": 923}, {"...  ...
#
#       revenue runtime                          spoken_languages    status  \
# 3  1084939099   165.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#            tagline                  title vote_average vote_count  \
# 3  The Legend Ends  The Dark Knight Rises          7.6       9106
#
# ...

# %%
df[df['genres'].str.contains('Drama')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#        budget                                             genres  \
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                        homepage   id  \
# 25  http://www.titanicmovie.com  597
#
#                                              keywords original_language  \
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
#
#    original_title                                           overview  \
# 25        Titanic  84 years later, a 101-year-old woman named Ros...
#
#     popularity                               production_companies  ...  \
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
#
#        revenue runtime                                   spoken_languages  \
# 25  1845034188   194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#       status                                    tagline    title vote_average  \
# 25  Released  Nothing on Earth could come between them.  Titanic          7.5
#
# ...

# %%
df[df['genres'].str.contains('Fantasy')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
# ...

# %%
df[df['genres'].str.contains('Family')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#         budget                                             genres  \
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
#
#                             homepage      id  \
# 124  http://movies.disney.com/frozen  109445
#
#                                               keywords original_language  \
# 124  [{"id": 2011, "name": "queen"}, {"id": 4344, "...                en
#
#     original_title                                           overview  \
# 124         Frozen  Young princess Anna of Arendelle dreams about ...
#
#      popularity                               production_companies  ...  \
# 124  165.125366  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#         revenue runtime                          spoken_languages    status  \
# 124  1274219009   102.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                tagline   title vote_average  \
# ...

# %%
df[df['genres'].str.contains('Romance')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#        budget                                             genres  \
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                        homepage   id  \
# 25  http://www.titanicmovie.com  597
#
#                                              keywords original_language  \
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
#
#    original_title                                           overview  \
# 25        Titanic  84 years later, a 101-year-old woman named Ros...
#
#     popularity                               production_companies  ...  \
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
#
#        revenue runtime                                   spoken_languages  \
# 25  1845034188   194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#       status                                    tagline    title vote_average  \
# 25  Released  Nothing on Earth could come between them.  Titanic          7.5
#
# ...

# %%
df[df['genres'].str.contains('Science Fiction')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#       revenue runtime                                   spoken_languages  \
# 0  2787965087   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
# ...

# %%
df[df['genres'].str.contains('Thriller')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#        budget                                             genres  \
# 25  200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                        homepage   id  \
# 25  http://www.titanicmovie.com  597
#
#                                              keywords original_language  \
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
#
#    original_title                                           overview  \
# 25        Titanic  84 years later, a 101-year-old woman named Ros...
#
#     popularity                               production_companies  ...  \
# 25  100.025899  [{"name": "Paramount Pictures", "id": 4}, {"na...  ...
#
#        revenue runtime                                   spoken_languages  \
# 25  1845034188   194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
#
#       status                                    tagline    title vote_average  \
# 25  Released  Nothing on Earth could come between them.  Titanic          7.5
#
# ...

# %%
df[df['genres'].str.contains('TV Movie')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#       budget                                             genres homepage  \
# 3285       0  [{"id": 10770, "name": "TV Movie"}, {"id": 107...      NaN
#
#           id                                           keywords  \
# 3285  153397  [{"id": 470, "name": "spy"}, {"id": 6091, "nam...
#
#      original_language original_title  \
# 3285                en       Restless
#
#                                                overview  popularity  \
# 3285  A young woman finds out that her mother worked...    0.812776
#
#                                    production_companies  ... revenue runtime  \
# 3285  [{"name": "British Broadcasting Corporation (B...  ...       0   180.0
#
#                               spoken_languages    status tagline     title  \
# 3285  [{"iso_639_1": "en", "name": "English"}]  Released     NaN  Restless
#
#      vote_average vote_count  box_office_group            extracted_genres
# 3285          4.9          8        0-0.5 Bil.  [TV Movie, Romance, Drama]
#
# ...

# %%
df[df['genres'].str.contains('Documentary')].sort_values(by = 'revenue', ascending = False).head(1)
# Out:
#        budget                                             genres  \
# 3861  8000000  [{"id": 99, "name": "Documentary"}, {"id": 107...
#
#                                              homepage    id  \
# 3861  http://empereur.luc-jacquet.com/index_flash.htm  1667
#
#                                                keywords original_language  \
# 3861  [{"id": 970, "name": "parents kids relationshi...                fr
#
#                original_title  \
# 3861  La Marche de l'empereur
#
#                                                overview  popularity  \
# 3861  Every year, thousands of Antartica's emperor p...   17.537154
#
#                                    production_companies  ...    revenue  \
# 3861  [{"name": "Wild Bunch", "id": 856}, {"name": "...  ...  127392239
#
#      runtime                                   spoken_languages    status  \
# 3861    80.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
# ...

# %% [markdown]
# # Further Insights for the Future
#
# If I could do more on this, I think I would definitely look into the Nulls within the data, as I noticed that there were quite a few, and would have summarised the best ways to remove each of the nulls depending on the amount missing in each column.
#
# Furthermore, I feel like perhaps doing some practice on my technical skills to do some deeper further searches into certain sectors such as looking into the Genres and Keywords section. However I am confident that this will come with consistent practice.
